# %% [markdown]
# - input/Output
# - variables
# - array/list
# - condition
# - loop
# - function

# %%
x = int(input("Enter number: "))

# %%
print("Hello World")
# Out:
# Hello World

# %%
num = 123345634636634

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
num = int(input("Enter number: "))
print(type(num))
# Out:
# <class 'int'>

# %% [markdown]
# Array/list

# %%
arr =[1,2,3,4,5]

# %%
arr
# Out:
# [1, 2, 3, 4, 5]

# %%
arr[0]
# Out:
# 1

# %%
arr[3] = 88
arr
len(arr)
arr[len(arr)-1]
# Out:
# 5
